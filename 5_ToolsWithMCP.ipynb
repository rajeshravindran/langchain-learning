# %%
import utility as ut

OPENAI_API_KEY = ut.OPENAI_API_KEY
LANGSMITH_API_KEY = ut.LANGSMITH_API_KEY
MODEL_NAME = ut.MODEL_NAME

# %%
import sys
print(sys.executable)
# Out:
# /Users/mia/myenv/bin/python3.11

# %% [markdown]
# MCP - Open standard Protocl which create an interface between toos and model

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import nest_asyncio
import asyncio

nest_asyncio.apply()

mcp_client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "npx",
            "args": [ "-y", "@theo.foobar/mcp-time"],
        }
    },
)


mcp_tools = await mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} MCP Tools: {[t.name for t in mcp_tools]}")
# Out:
# Loaded 5 MCP Tools: ['add_time', 'compare_time', 'convert_timezone', 'current_time', 'relative_time']

# %%
from langchain.agents import create_agent

agent_with_mcp = create_agent(
    model = MODEL_NAME,
    tools = mcp_tools,
    system_prompt = "you are a helpful assistant",
)

# %%
result = await agent_with_mcp.ainvoke(
    {
        "messages": [
            {
                "role":"user",
                "content":"what is the time in London right now?"
            }
        ]
    }
)

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# /Users/mia/myenv/lib/python3.11/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# ================================ Human Message =================================
#
# what is the time in London right now?
# ================================== Ai Message ==================================
# Tool Calls:
#   current_time (call_fuTzVovgRICOo37BokOg3nWB)
#  Call ID: call_fuTzVovgRICOo37BokOg3nWB
#   Args:
#     timezone: Europe/London
# ================================= Tool Message =================================
# Name: current_time
#
# 2025-11-19T06:28:58Z
# ================================== Ai Message ==================================
#
# The current time in London is 06:28 AM on November 19, 2025.
